# %% [markdown]
# # Week 5: Train-Test Split with Telco Churn
#
# This is the **student version** of the Week 5 notebook.
#
# Your job is to fill in the missing code cells as you work through the activity.

# %% [markdown]
# ## What you will practise
#
# In this notebook you will:
#
# - import the Python tools you need
# - load a CSV into pandas
# - inspect a DataFrame
# - split one table into train and test tables
# - see what `random_state` and `test_size` do
#
# The goal is not to build a full model yet. The goal is just to understand the split.

# %% [markdown]
# ## Preparation
#
# This notebook expects `WA_Fn-UseC_-Telco-Customer-Churn.csv` to be in the same folder.
#
# Open it in Jupyter Notebook on your own machine or in Google Colab.

# %% [markdown]
# ## Step 1: Import the tools
#
# ### Your turn
# Import pandas as `pd`, and import `train_test_split` from `sklearn.model_selection`.

# %%
# TODO: add the two import lines here
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Step 2: Load the CSV
#
# ### Your turn
# Create a DataFrame called `telco` by reading `WA_Fn-UseC_-Telco-Customer-Churn.csv`.

# %%
# TODO: load the CSV into a DataFrame called telco
telco = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# When that works, run the next cell to look at the first few rows.

# %%
telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Step 3: Inspect the columns
#
# A pandas DataFrame is just a table. Each row is one customer, and each column is one variable.

# %%
telco.columns.tolist()
# Out:
# ['customerID',
#  'gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %% [markdown]
# ## Step 4: Look at a few useful columns
#
# ### Your turn
# Show the first few rows of just these four columns:
#
# - `SeniorCitizen`
# - `tenure`
# - `MonthlyCharges`
# - `Churn`

# %%
# TODO: show those four columns and use .head()
telco[['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn']].head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges Churn
# 0              0       1           29.85    No
# 1              0      34           56.95    No
# 2              0       2           53.85   Yes
# 3              0      45           42.30    No
# 4              0       2           70.70   Yes

# %% [markdown]
# ## Step 5: Split the table into train and test
#
# ### Your turn
# Use `train_test_split(telco)` and store the results in `df_train` and `df_test`. Then check the number of rows in each table.

# %%
# TODO: split telco into df_train and df_test
df_train, df_test = train_test_split(telco)

# TODO: show the two row counts
len(df_train), len(df_test)

df_train[['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn']].head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges Churn
# 6229              0      72           85.45    No
# 6319              1      54           24.95    No
# 5381              0      32           78.90   Yes
# 980               0      20           19.50    No
# 4815              0      38           70.45   Yes

# %% [markdown]
# ## Step 6: Run it again
#
# ### Your turn
# Make a second split called `df_train_again` and `df_test_again`. Then look at the first few rows of the new training table.
#
# What changed?

# %%
# TODO: make another split and inspect the first few rows
df_train_again, df_test_again = train_test_split(telco)
df_train_again[['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn']].head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges Churn
# 3526              1       5           50.35   Yes
# 1054              0      40           97.10   Yes
# 1352              0      72           60.95    No
# 2366              1       1           70.15   Yes
# 6736              0      67           20.80    No

# %% [markdown]
# ## Step 7: Make it repeatable with `random_state`
#
# ### Your turn
# Repeat the split, but this time use `random_state=42`. Then inspect the first few rows of the training table.

# %%
# TODO: use random_state=42
df_train_seeded, df_test_seeded = train_test_split(telco, random_state=240326)
df_train_seeded[['SeniorCitizen', 'tenure', 'MonthlyCharges', 'Churn']].head()
# Out:
#       SeniorCitizen  tenure  MonthlyCharges Churn
# 670               0      53           19.85    No
# 3823              0      72           78.85    No
# 3546              0      71           83.20    No
# 2822              0      41           79.90   Yes
# 986               0      12           43.80    No

# %% [markdown]
# ## Step 8: Choose how much to hold out with `test_size`
#
# ### Your turn
# Make another split with both `random_state=42` and `test_size=0.2`. Then create a tiny table showing how many rows are in:
#
# - the full data
# - the training set
# - the test set

# %%
# TODO: make a 20% test split
df_train_20, df_test_20 = train_test_split(telco, random_state=42, test_size=0.2)

# TODO: build a small DataFrame showing the row counts
pd.DataFrame([len(telco), len(df_train_20), len(df_test_20)])
# Out:
#       0
# 0  7043
# 1  5634
# 2  1409

# %% [markdown]
# ## Step 9: Which column would later be the target?
#
# If we later built a churn classifier, `Churn` would be the column we want to predict.
#
# Run the next cell to see how many customers are in each class.

# %%
telco['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ## Reflection questions
#
# Write short answers in your notes or underneath this cell.
#
# 1. What does `from sklearn.model_selection import train_test_split` mean?
# 2. Why did the split change from run to run at first?
# 3. What did `random_state=42` do?
# 4. What did `test_size=0.2` do?
# 5. Which column would later become the target for a churn classifier?
